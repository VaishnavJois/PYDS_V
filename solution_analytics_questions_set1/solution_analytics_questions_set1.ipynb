# %%
import pandas as pd

# %%
#1. Load the file Salaries.csv and get data into DataFrame. Get all the columns
salaries = pd.read_csv('Salaries.csv')
salaries=pd.DataFrame(salaries)
salaries
# salaries.dtypes
# Out:
# C:\Users\MITE\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY        167411
# 1                      CAPTAIN III (POLICE DEPARTMENT)        155966
# 2                      CAPTAIN III (POLICE DEPARTMENT)        212739
# ...

# %%
#2. Get the count of number of rows and number of columns.
rows,columns = salaries.shape
print(f'rows : {rows}')
# print(f'columns : {columns}')
# Out:
# rows : 148654

# %%
# 3. Get the Average BasePay.
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"],errors='coerce')
salaries["BasePay"] = salaries['BasePay'].fillna(0)

# %%
base_pay = sum(salaries['BasePay'])/rows
base_pay
# Out:
# 66053.72928809702

# %%
base_pay = avg_base_pay['Id']
base_pay
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 148645    148646
# 148647    148648
# 148648    148649
# 148649    148650
# 148653    148654
# Name: Id, Length: 148650, dtype: int64

# %%
#4.What is the highest BasePay?
salaries['BasePay'].max()
# Out:
# 319275.01

# %%
#5. Display the all unique values of JobTitle.
print(salaries["JobTitle"].unique())
print(len(salaries["JobTitle"].unique()))
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'
#  'CAPTAIN III (POLICE DEPARTMENT)' 'WIRE ROPE CABLE MAINTENANCE MECHANIC'
#  ... 'Conversion' 'Cashier 3' 'Not provided']
# 2159

# %%
#6. Display the EmployeeName, JobTitle, andBasePay of the 5 highest paid employees (based upon BasePay).
salaries.nlargest(5, ['BasePay'])
# Out:
#             Id          EmployeeName                      JobTitle    BasePay  \
# 72925    72926        Gregory P Suhr               Chief of Police  319275.01
# 110532  110533            Amy P Hart             Asst Med Examiner  318835.49
# 72929    72930         Robert L Shaw  Dep Dir for Investments, Ret  315572.01
# 72926    72927  Joanne M Hayes-White        Chief, Fire Department  313686.01
# 72931    72932     Harlan L Kelly-Jr   Executive Contract Employee  313312.52
#
#        OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 72925            0  20007.1  86533.2  339282.07         425815.28  2013
# 110532       10713  60563.5  89540.2  390111.98         479652.21  2014
# 72929            0        0  82849.7  315572.01         398421.67  2013
# 72926            0    23236  85431.4  336922.01         422353.40  2013
# 72931            0        0  82319.5  313312.52         395632.03  2013
#
#         Notes         Agency Status
# ...

# %%
#7.What is the BasePay of "DAVID SULLIVAN"?
salaries.loc[salaries["EmployeeName"] == "DAVID SULLIVAN"]
# Out:
#           Id    EmployeeName                   JobTitle   BasePay OvertimePay  \
# 5          6  DAVID SULLIVAN  ASSISTANT DEPUTY CHIEF II  118602.0        8601
# 10120  10121  DAVID SULLIVAN                PLANNER III   94758.0           0
#
#       OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 5       189083      NaN  316285.74         316285.74  2011    NaN
# 10120  1716.92      NaN   96474.92          96474.92  2011    NaN
#
#               Agency Status
# 5      San Francisco    NaN
# 10120  San Francisco    NaN

# %%
#8. Display the EmployeeName, JobTitle, and BasePayof those people whose JobTitle is "CAPTAIN, FIRE SUPPRESSION".
salaries.loc[salaries["JobTitle"] == "CAPTAIN, FIRE SUPPRESSION"]
# Out:
#           Id      EmployeeName                   JobTitle    BasePay  \
# 22        23     GEORGE GARCIA  CAPTAIN, FIRE SUPPRESSION  140546.88
# 24        25   JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86
# 26        27       JOHN HANLEY  CAPTAIN, FIRE SUPPRESSION   92080.80
# 52        53  MICHAEL ROLOVICH  CAPTAIN, FIRE SUPPRESSION  140546.87
# 53        54     DARRYL HUNTER  CAPTAIN, FIRE SUPPRESSION  140546.88
# ...      ...               ...                        ...        ...
# 3201    3202     GREGORY JONES  CAPTAIN, FIRE SUPPRESSION  125820.24
# 3283    3284     BRITTON SMITH  CAPTAIN, FIRE SUPPRESSION  127886.02
# 7223    7224   WILLIAM BARTELS  CAPTAIN, FIRE SUPPRESSION   65222.55
# 8684    8685     JEANNE SEYLER  CAPTAIN, FIRE SUPPRESSION   95055.34
# 34124  34125     JOHN FORBES-3  CAPTAIN, FIRE SUPPRESSION       0.00
#
#       OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# ...

# %%
#9. Display the EmployeeName,JobTitle, and BasePayof those people whose JobTitlecontains the word "CHIEF".
salaries[salaries["JobTitle"].str.contains('CHIEF')]
# Out:
#           Id        EmployeeName  \
# 4          5     PATRICK GARDNER
# 5          6      DAVID SULLIVAN
# 6          7           ALSON LEE
# 8          9      MICHAEL MORRIS
# 9         10  JOANNE HAYES-WHITE
# ...      ...                 ...
# 31735  31736        BRENT POWELL
# 32623  32624        JAMES BARDEN
# 33386  33387        NORMAN DALEY
# 34535  34536           SIMON LEE
# 35207  35208        PATRICK BOYD
#
#                                            JobTitle    BasePay OvertimePay  \
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60        9737
# 5                         ASSISTANT DEPUTY CHIEF II  118602.00        8601
# 6                BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01     89062.9
# 8                BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64     86362.7
# 9            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00           0
# ...                                             ...        ...         ...
# ...

# %%
#10.Display the EmployeeName of the person who is getting the lowest salary (based upon TotalPay).
tpaylow = min(salaries['TotalPay'])
tpaylow
# Out:
# -618.13

# %%
#11. Get the EmployeeNameof those people who are getting TotalPayof zero (0) or less.
ltz_tpay = salaries.loc[salaries['TotalPay'] <= 0]
ltz_tpay
# Out:
#             Id        EmployeeName  \
# 36156    36157      PAULETTE ADAMS
# 36157    36158       KAUKAB MOHSIN
# 36158    36159  JOSEPHINE MCCREARY
# 70877    70878       Roland Baylon
# 70927    70928    Felecia Phillips
# ...        ...                 ...
# 148649  148650       Roy I Tillery
# 148650  148651        Not provided
# 148651  148652        Not provided
# 148652  148653        Not provided
# 148653  148654           Joe Lopez
#
#                                           JobTitle  BasePay   OvertimePay  \
# 36156   STATIONARY ENGINEER, WATER TREATMENT PLANT      0.0             0
# 36157                             TRANSIT OPERATOR      0.0             0
# 36158                                   MANAGER IV      0.0             0
# 70877                        Deputy Court Clerk II      0.0             0
# 70927                             Registered Nurse      0.0             0
# ...                                            ...      ...           ...
# ...

# %%
#12. Get the Average salary (TotalPay) of the people by year.
avg_tpay = salaries.groupby(['Year']).mean()
avg_tpay
# Out:
#             Id       BasePay      TotalPay  TotalPayBenefits  Notes
# Year
# 2011   18080.0  63595.956517  71744.103871      71744.103871    NaN
# 2012   54542.5  65436.406857  74113.262265     100553.229232    NaN
# 2013   91728.5  68509.832156  77611.443142     101440.519714    NaN
# 2014  129593.0  66557.437750  75463.918140     100250.918884    NaN

# %%
#13. Get the count of Employees by JobTitle and display the top 5.
j_title = salaries["JobTitle"].value_counts().head()
print(j_title)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
#14. Get the Employees whose name starts with "R" and ends with "n".
rn_name = salaries[salaries["EmployeeName"].str.contains('^R.*n$')]
print(rn_name)
# Out:
#             Id     EmployeeName                      JobTitle    BasePay  \
# 36176    36177   Raymond Guzman   Dep Chf of Dept (Fire Dept)  244102.02
# 36527    36528      Ruby Martin              Registered Nurse  174044.89
# 36564    36565  Richard Untalan  Lieutenant, Fire Suppression  128808.89
# 36567    36568       Ryan Crean  Lieutenant, Fire Suppression  128808.86
# 36585    36586     Robert Bryan    Assistant Chief Attorney 1  189937.60
# ...        ...              ...                           ...        ...
# 148435  148436  Rebecca Woodson    BdComm Mbr, Grp2,M=$25/Mtg     175.00
# 148520  148521   Robert J Gowan                  Truck Driver       0.00
# 148610  148611    Ruby S Martin                 Special Nurse      21.22
# 148625  148626  Renato C Gurion              Registered Nurse       0.00
# 148644  148645     Randy D Winn  Stationary Eng, Sewage Plant       0.00
#
#        OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
#15.Create a pivot table, and experiment with it.
salaries.pivot_table(index=['JobTitle'], values=['TotalPay'], aggfunc='sum')
# Out:
#                                                   TotalPay
# JobTitle
# ACCOUNT CLERK                                   3654960.14
# ACCOUNTANT                                       237146.34
# ACCOUNTANT INTERN                               1393523.66
# ACPO,JuvP, Juv Prob (SFERS)                       62290.78
# ACUPUNCTURIST                                     67594.40
# ...                                                    ...
# X-RAY LABORATORY AIDE                           1370352.89
# X-Ray Laboratory Aide                           5082394.27
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.87
# Youth Comm Advisor                               165657.23
# ZOO CURATOR                                       66686.56
#
# [2159 rows x 1 columns]
